# %% [markdown]
# # DNN Assignment
# In this assignment you are working together with your teammates from the second project. You will apply your new knowledge about dense neural networks to the data from your ML project to investigate, if you can make further improvements on prediction performance. Your data is (hopefully) already cleaned and transformed (this was part of your ML project) such that you can focus fully on feeding it to your neural network. Use TensorFlow 2.x in this assignment as it makes training with real-life data much more easier with many implemented features (e.g. early-stopping, TensorBoard, regularization, etc.).
#
# In this notebook you will learn
# - how to apply a neural network to your own data using TensorFlow 2.x
# - how to tune the network and monitor learning
# - how to train several networks and ensemble them into a stronger model

# %% [markdown]
# # Module loading
# Load all the necessary packages for your assignment. We give you some modules in advance, feel free to add more, if you need them.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers
from tensorflow.keras import regularizers
    
print('Using TensorFlow version: %s' % tf.__version__)
# Out:
# Using TensorFlow version: 2.8.0

# %%
#!pip install -q git+https://github.com/tensorflow/docs
    
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots
import datetime, time, os

# %%
from sklearn.pipeline import Pipeline # focus on this one
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import cross_val_predict, cross_val_score, cross_validate
from sklearn.metrics import roc_curve, confusion_matrix, accuracy_score, recall_score, precision_score
from sklearn import preprocessing
from sklearn import utils
from sklearn.metrics import mean_squared_error, accuracy_score, recall_score, roc_auc_score, f1_score, roc_curve, r2_score, fbeta_score,cohen_kappa_score, f1_score

# %% [markdown]
# ## Data loading
# Load here your data from your ML project. You can use either `pandas` or `numpy` to format your data.

# %%
# Load data
df = pd.read_pickle("df_train_1.pkl")
df
# Out:
#              Date Place_ID  target  target_min  target_max  target_variance  \
# 0      2020-01-02  010Q650    38.0        23.0        53.0           769.50
# 1      2020-01-03  010Q650    39.0        25.0        63.0          1319.85
# 2      2020-01-04  010Q650    24.0         8.0        56.0          1181.96
# 3      2020-01-05  010Q650    49.0        10.0        55.0          1113.67
# 4      2020-01-06  010Q650    21.0         9.0        52.0          1164.82
# ...           ...      ...     ...         ...         ...              ...
# 30552  2020-03-15  YWSFY6Q    22.0        14.0        83.0          3848.86
# 30553  2020-03-16  YWSFY6Q    53.0        30.0       146.0          9823.87
# 30554  2020-03-17  YWSFY6Q    85.0        52.0       153.0          8900.85
# 30555  2020-03-18  YWSFY6Q   103.0        33.0       149.0         13963.90
# 30556  2020-03-19  YWSFY6Q    89.0        46.0       132.0          9393.64
#
#        target_count  precipitable_water_entire_atmosphere  \
# 0                92                             11.000000
# 1                91                             14.600000
# 2                96                             16.400000
# 3                96                              6.911948
# 4                95                             13.900001
# ...             ...                                   ...
# 30552            72                              6.700000
# 30553            72                              6.300000
# 30554            72                              7.100000
# 30555            72                             19.100000
# 30556            72                             11.600000
#
#        relative_humidity_2m_above_ground  specific_humidity_2m_above_ground  \
# 0                              60.200001                            0.00804
# 1                              48.799999                            0.00839
# 2                              33.400002                            0.00750
# 3                              21.300001                            0.00391
# 4                              44.700001                            0.00535
# ...                                  ...                                ...
# 30552                          68.300003                            0.00352
# 30553                          77.700005                            0.00341
# 30554                          68.500000                            0.00356
# 30555                          66.300003                            0.00523
# 30556                          68.400002                            0.00486
#
#        ...  L3_NO2_cloud_fraction  L3_CO_CO_column_number_density  \
# 0      ...               0.006507                        0.021080
# 1      ...               0.018360                        0.022017
# 2      ...               0.015904                        0.020677
# 3      ...               0.055765                        0.021207
# 4      ...               0.028530                        0.037766
# ...    ...                    ...                             ...
# 30552  ...               0.001107                        0.039941
# 30553  ...               0.004726                        0.037872
# 30554  ...               0.026249                        0.038539
# 30555  ...               0.144318                        0.038757
# 30556  ...               0.030848                             NaN
#
#        L3_CO_cloud_height  L3_HCHO_tropospheric_HCHO_column_number_density  \
# 0              267.017184                                         0.000064
# 1               61.216687                                         0.000171
# 2              134.700335                                         0.000124
# 3              474.821444                                         0.000081
# 4              926.926310                                         0.000140
# ...                   ...                                              ...
# 30552          192.388239                                         0.000024
# 30553           61.379434                                        -0.000014
# 30554         1572.596434                                         0.000094
# 30555          846.961465                                         0.000063
# 30556                 NaN                                              NaN
#
#        L3_HCHO_cloud_fraction  L3_O3_O3_column_number_density  \
# 0                    0.000000                        0.119095
# 1                    0.059433                        0.115179
# 2                    0.082063                        0.115876
# 3                    0.121261                        0.141557
# 4                    0.037919                        0.126369
# ...                       ...                             ...
# 30552                0.001310                        0.174995
# 30553                0.007644                        0.157659
# 30554                0.025447                        0.168295
# 30555                0.103292                        0.160637
# 30556                     NaN                             NaN
#
#        L3_O3_cloud_fraction  L3_SO2_SO2_column_number_density  \
# 0                  0.000000                         -0.000127
# 1                  0.059433                          0.000150
# 2                  0.082063                          0.000150
# 3                  0.121261                          0.000227
# 4                  0.037919                          0.000390
# ...                     ...                               ...
# 30552              0.001310                          0.000312
# 30553              0.007644                          0.000362
# 30554              0.025447                          0.000107
# 30555              0.173391                          0.000014
# 30556                   NaN                               NaN
#
#        L3_SO2_absorbing_aerosol_index  L3_SO2_cloud_fraction
# 0                           -1.861476               0.000000
# 1                           -1.452612               0.059433
# 2                           -1.572950               0.082063
# 3                           -1.239317               0.121261
# 4                            0.202489               0.037919
# ...                               ...                    ...
# 30552                       -1.953480               0.001310
# 30553                       -2.178236               0.007644
# 30554                       -2.365827               0.025447
# 30555                       -2.784346               0.153445
# 30556                             NaN                    NaN
#
# [30557 rows x 29 columns]

# %%
# create windstrength column
df['windstrength'] = np.sqrt(df.u_component_of_wind_10m_above_ground**2 + df.v_component_of_wind_10m_above_ground**2)
df.windstrength.describe()
# Out:
# count    30557.000000
# mean         3.100731
# std          2.209016
# min          0.020040
# 25%          1.497562
# 50%          2.545925
# 75%          4.152956
# max         18.160623
# Name: windstrength, dtype: float64

# %%
import pandas as pd
from datetime import datetime, date, time, timedelta

# %%
# change date to datetime
df.Date = pd.to_datetime(df['Date'], format='%Y-%m-%d')

# change date to datetime
df['weekday'] = df.Date.dt.dayofweek

# Dropping the unnecessary columns 
df.drop(['Date',
         #'Place_ID',
         'target_min',
         'target_max',
         'target_variance',
         'target_count',
         'u_component_of_wind_10m_above_ground',
         'v_component_of_wind_10m_above_ground',
         ], axis=1, inplace=True)
df.columns

df.dropna(thresh=len(df.columns)-8, inplace=True)

df = df.reset_index(drop=True)

df["target"] = pd.cut(df.target, bins=[0, 35, 115, 850], labels=['0', '1', '2'])

# %%
# Creating list for categorical predictors/features 
# (dates are also objects so if you have them in your data you would deal with them first)
cat_features = list(df.columns[df.dtypes==object])


# Creating list for categorical predictors/features 
# (dates are also objects so if you have them in your data you would deal with them first)
time_features = ['weekday']


# Creating list for numerical predictors/features
# Since 'target' is our target variable we will exclude this feature from this list of numerical predictors 
num_features = [#'target_min', 'target_max', 'target_variance', 'target_count',
       'precipitable_water_entire_atmosphere',
       'relative_humidity_2m_above_ground',
       'specific_humidity_2m_above_ground',
       'temperature_2m_above_ground',
       #'u_component_of_wind_10m_above_ground',
       #'v_component_of_wind_10m_above_ground'
       'windstrength'
       ]


# Creating list for numerical predictors/features
# Since 'outcome' is our target variable we will exclude this feature from this list of numerical predictors 
miss_features = ['L3_AER_AI_absorbing_aerosol_index', 
       'L3_CLOUD_cloud_base_height',
       'L3_CLOUD_cloud_fraction', 
       'L3_CLOUD_cloud_optical_depth',
       'L3_NO2_NO2_column_number_density',
       'L3_NO2_cloud_fraction', 
       'L3_CO_cloud_height',
       'L3_HCHO_tropospheric_HCHO_column_number_density',
       'L3_HCHO_cloud_fraction', 
       'L3_SO2_SO2_column_number_density',
       'L3_SO2_cloud_fraction']


replace_features = ["L3_NO2_absorbing_aerosol_index",
                    "L3_CO_CO_column_number_density",
                    "L3_O3_O3_column_number_density",
                    "L3_O3_cloud_fraction",
                    "L3_SO2_absorbing_aerosol_index"]

# %%
# Define predictors and target variable
X = df.drop('target', axis=1)
y = df['target']
print(f"We have {X.shape[0]} observations in our dataset and {X.shape[1]} features")
print(f"Our target vector has also {y.shape[0]} values")
# Out:
# We have 28613 observations in our dataset and 23 features
# Our target vector has also 28613 values

# %%
# Split into train and test set 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y_train = y_train.astype(int)

# %%
num_pipeline = Pipeline([
    ('std_scaler', StandardScaler())
])
# Pipeline for missing values: in this case missing values are nan!
miss_pipeline = Pipeline([
    ('imputer_num', SimpleImputer(strategy='median',missing_values=np.nan)),
    ('std_scaler', StandardScaler())
])
# replace 0 values
# Pipeline for missing values: in this case missing values are 0!
replace_pipeline = Pipeline([
    ('imputer_null', SimpleImputer(strategy='constant', fill_value = 0)),
    ('imputer_nan', SimpleImputer(strategy='median', missing_values= 0)),
    ('std_scaler', StandardScaler())
])

# Pipeline for categorical features 
cat_pipeline = Pipeline([
    #('imputer_cat', SimpleImputer(strategy='constant',fill_value='missing')),
    ('1hot', OneHotEncoder(handle_unknown='ignore'))
])

# Pipeline for categorical features 
time_pipeline = Pipeline([
    #('imputer_cat', SimpleImputer(strategy='constant',fill_value='missing')),
    ('1hot', OneHotEncoder(handle_unknown='ignore'))
    ])

#from sklearn.compose import ColumnTransformer

# Complete pipeline for numerical and categorical features
preprocessor = ColumnTransformer([
    ('num', num_pipeline, num_features),
    ('cat', cat_pipeline, cat_features),
    ('miss', miss_pipeline, miss_features),
    ('replace', replace_pipeline, replace_features),
    ('time', time_pipeline, time_features)
    ], sparse_threshold=0)

# %%
X_train_transformed = preprocessor.fit_transform(X_train)

# %%
X_train_transformed.shape

X_tf_train = tf.convert_to_tensor(X_train_transformed)
y_tf_train = tf.convert_to_tensor(y_train)
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-02-22 15:47:00.773607: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-22 15:47:00.773736: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Training
# For training you need a train/val split (hopefully you did a train/test split before (and you should use the same as in your ML project to make results comparable).

# %%
# Define dictionary to store results
training_history = {}

# Define number of epochs and learning rate decay
N_TRAIN = len(X_train)
N_VAL = 0.2
EPOCHS = 200
BATCH_SIZE = N_TRAIN // 10
STEPS_PER_EPOCH = N_TRAIN // BATCH_SIZE
# lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
#     0.01,
#     decay_steps=STEPS_PER_EPOCH*1000,
#     decay_rate=1,
#     staircase=False)

# %% [markdown]
# ### Build, compile and fit your model
# To become fast at retraining your (different) models it is good practice to define a function that gets fed by a model, its name, an optimizer to use and the number of epochs you want the model to be trained.
#
# If your model trains for many epochs you will receive a lot of logging from TensorFlow. To reduce the logging noise you can use a callback (provided by the `tensorflow_docs` module we installed and imported for you) named `EpochDots()` that simply prints a `.` for each epoch and a full set of metrics after a number of epochs have been trained.
#
# If you want to produce logs for using TensorBoard you also need to include the `callbacks.TensorBoard()`.

# %%
from datetime import datetime
# Define path for new directory 
root_logdir = os.path.join(os.curdir, "my_logs")

# Define function for creating a new folder for each run
def get_run_logdir():
    now = datetime.now()
    run_id = now.strftime('%Y-%m-%d %H:%M:%S')
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir()

# %%
#def get_callbacks():
# Define path where checkpoints should be stored
checkpoint_path = "training_1/ML_model.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=0) # Set verbose != 0 if you want output during training 
# return [list of your callbacks]
def get_callbacks(name):
    return tf.keras.callbacks.TensorBoard(run_logdir+name, histogram_freq=1)

# %% [markdown]
# You can implement your callbacks in the `model.fit()` method below.

# %%
def model_compile_and_fit(model, name, optimizer=None, max_epochs=EPOCHS):
  
    # model.compile

    model.compile(optimizer = 'sgd', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
    
    # model.fit

    history = model.fit(X_tf_train, y_train, batch_size = BATCH_SIZE, validation_split=N_VAL, epochs = max_epochs)
    # return results
    # return {name:history}
    return history

# %% [markdown]
# #### Build your model
# You can build your model by using `tf.keras.Sequential()` that helps you to sequentially define your different layers from input to output.

# %%
with tf.device('/cpu:0'):
    model = tf.keras.Sequential([
    tf.keras.layers.Dense(units = 9, kernel_initializer = 'uniform', activation = 'relu', input_dim = 368),
    tf.keras.layers.Dense(units = 9, kernel_initializer = 'uniform', activation = 'relu'),
    tf.keras.layers.Dense(units= 3,kernel_initializer = 'uniform', activation = 'softmax')
    ])

# %% [markdown]
# #### Train your model
# Train your model by using your `model_compile_and_fit()` function you defined above.

# %%
#your_history = model_compile_and_fit(your_model, ....)
with tf.device('/cpu:0'):
    training_history["firstmodel"] = model_compile_and_fit(model, "firstmodel")
# Out:
# Epoch 1/200
# 2023-02-22 15:47:01.121407: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 9/9 [==============================] - 1s 26ms/step - loss: 1.0960 - accuracy: 0.4887 - val_loss: 1.0920 - val_accuracy: 0.5112
# Epoch 2/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0893 - accuracy: 0.5215 - val_loss: 1.0866 - val_accuracy: 0.5112
# Epoch 3/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0840 - accuracy: 0.5215 - val_loss: 1.0801 - val_accuracy: 0.5112
# Epoch 4/200
# 9/9 [==============================] - 0s 10ms/step - loss: 1.0775 - accuracy: 0.5215 - val_loss: 1.0760 - val_accuracy: 0.5112
# Epoch 5/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0734 - accuracy: 0.5215 - val_loss: 1.0702 - val_accuracy: 0.5112
# Epoch 6/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0676 - accuracy: 0.5215 - val_loss: 1.0655 - val_accuracy: 0.5112
# Epoch 7/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0629 - accuracy: 0.5215 - val_loss: 1.0610 - val_accuracy: 0.5112
# Epoch 8/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0585 - accuracy: 0.5215 - val_loss: 1.0565 - val_accuracy: 0.5112
# Epoch 9/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0540 - accuracy: 0.5215 - val_loss: 1.0530 - val_accuracy: 0.5112
# Epoch 10/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0505 - accuracy: 0.5215 - val_loss: 1.0484 - val_accuracy: 0.5112
# Epoch 11/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0459 - accuracy: 0.5215 - val_loss: 1.0441 - val_accuracy: 0.5112
# Epoch 12/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0415 - accuracy: 0.5215 - val_loss: 1.0403 - val_accuracy: 0.5112
# Epoch 13/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0378 - accuracy: 0.5215 - val_loss: 1.0367 - val_accuracy: 0.5112
# Epoch 14/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0342 - accuracy: 0.5215 - val_loss: 1.0341 - val_accuracy: 0.5112
# Epoch 15/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0315 - accuracy: 0.5215 - val_loss: 1.0312 - val_accuracy: 0.5112
# Epoch 16/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0287 - accuracy: 0.5215 - val_loss: 1.0283 - val_accuracy: 0.5112
# Epoch 17/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0258 - accuracy: 0.5215 - val_loss: 1.0262 - val_accuracy: 0.5112
# Epoch 18/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0237 - accuracy: 0.5215 - val_loss: 1.0237 - val_accuracy: 0.5112
# Epoch 19/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0211 - accuracy: 0.5215 - val_loss: 1.0211 - val_accuracy: 0.5112
# Epoch 20/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0185 - accuracy: 0.5215 - val_loss: 1.0187 - val_accuracy: 0.5112
# Epoch 21/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0160 - accuracy: 0.5215 - val_loss: 1.0165 - val_accuracy: 0.5112
# Epoch 22/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0139 - accuracy: 0.5215 - val_loss: 1.0142 - val_accuracy: 0.5112
# Epoch 23/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0115 - accuracy: 0.5215 - val_loss: 1.0126 - val_accuracy: 0.5112
# Epoch 24/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0099 - accuracy: 0.5215 - val_loss: 1.0108 - val_accuracy: 0.5112
# Epoch 25/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0081 - accuracy: 0.5215 - val_loss: 1.0092 - val_accuracy: 0.5112
# Epoch 26/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0065 - accuracy: 0.5215 - val_loss: 1.0073 - val_accuracy: 0.5112
# Epoch 27/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0045 - accuracy: 0.5215 - val_loss: 1.0055 - val_accuracy: 0.5112
# Epoch 28/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0027 - accuracy: 0.5215 - val_loss: 1.0041 - val_accuracy: 0.5112
# Epoch 29/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0013 - accuracy: 0.5215 - val_loss: 1.0027 - val_accuracy: 0.5112
# Epoch 30/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0000 - accuracy: 0.5215 - val_loss: 1.0014 - val_accuracy: 0.5112
# Epoch 31/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9986 - accuracy: 0.5215 - val_loss: 1.0003 - val_accuracy: 0.5112
# Epoch 32/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9975 - accuracy: 0.5215 - val_loss: 0.9990 - val_accuracy: 0.5112
# Epoch 33/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9962 - accuracy: 0.5215 - val_loss: 0.9979 - val_accuracy: 0.5112
# Epoch 34/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9952 - accuracy: 0.5215 - val_loss: 0.9969 - val_accuracy: 0.5112
# Epoch 35/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9941 - accuracy: 0.5215 - val_loss: 0.9957 - val_accuracy: 0.5112
# Epoch 36/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9929 - accuracy: 0.5215 - val_loss: 0.9950 - val_accuracy: 0.5112
# Epoch 37/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9921 - accuracy: 0.5215 - val_loss: 0.9941 - val_accuracy: 0.5112
# Epoch 38/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9912 - accuracy: 0.5215 - val_loss: 0.9933 - val_accuracy: 0.5112
# Epoch 39/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9904 - accuracy: 0.5215 - val_loss: 0.9926 - val_accuracy: 0.5112
# Epoch 40/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9896 - accuracy: 0.5215 - val_loss: 0.9918 - val_accuracy: 0.5112
# Epoch 41/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9889 - accuracy: 0.5215 - val_loss: 0.9911 - val_accuracy: 0.5112
# Epoch 42/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9881 - accuracy: 0.5215 - val_loss: 0.9903 - val_accuracy: 0.5112
# Epoch 43/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9874 - accuracy: 0.5215 - val_loss: 0.9897 - val_accuracy: 0.5112
# Epoch 44/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9868 - accuracy: 0.5215 - val_loss: 0.9889 - val_accuracy: 0.5112
# Epoch 45/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9861 - accuracy: 0.5215 - val_loss: 0.9885 - val_accuracy: 0.5112
# Epoch 46/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9857 - accuracy: 0.5215 - val_loss: 0.9878 - val_accuracy: 0.5112
# Epoch 47/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9850 - accuracy: 0.5215 - val_loss: 0.9873 - val_accuracy: 0.5112
# Epoch 48/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9845 - accuracy: 0.5215 - val_loss: 0.9870 - val_accuracy: 0.5112
# Epoch 49/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9842 - accuracy: 0.5215 - val_loss: 0.9866 - val_accuracy: 0.5112
# Epoch 50/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9838 - accuracy: 0.5215 - val_loss: 0.9863 - val_accuracy: 0.5112
# Epoch 51/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9834 - accuracy: 0.5215 - val_loss: 0.9858 - val_accuracy: 0.5112
# Epoch 52/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9830 - accuracy: 0.5215 - val_loss: 0.9852 - val_accuracy: 0.5112
# Epoch 53/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9824 - accuracy: 0.5215 - val_loss: 0.9849 - val_accuracy: 0.5112
# Epoch 54/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9821 - accuracy: 0.5215 - val_loss: 0.9845 - val_accuracy: 0.5112
# Epoch 55/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9817 - accuracy: 0.5215 - val_loss: 0.9841 - val_accuracy: 0.5112
# Epoch 56/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9813 - accuracy: 0.5215 - val_loss: 0.9838 - val_accuracy: 0.5112
# Epoch 57/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9809 - accuracy: 0.5215 - val_loss: 0.9833 - val_accuracy: 0.5112
# Epoch 58/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9804 - accuracy: 0.5215 - val_loss: 0.9828 - val_accuracy: 0.5112
# Epoch 59/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9800 - accuracy: 0.5215 - val_loss: 0.9824 - val_accuracy: 0.5112
# Epoch 60/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9796 - accuracy: 0.5215 - val_loss: 0.9820 - val_accuracy: 0.5112
# Epoch 61/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9791 - accuracy: 0.5215 - val_loss: 0.9818 - val_accuracy: 0.5112
# Epoch 62/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9789 - accuracy: 0.5215 - val_loss: 0.9816 - val_accuracy: 0.5112
# Epoch 63/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9788 - accuracy: 0.5215 - val_loss: 0.9812 - val_accuracy: 0.5112
# Epoch 64/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9784 - accuracy: 0.5215 - val_loss: 0.9811 - val_accuracy: 0.5112
# Epoch 65/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9782 - accuracy: 0.5215 - val_loss: 0.9807 - val_accuracy: 0.5112
# Epoch 66/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9779 - accuracy: 0.5215 - val_loss: 0.9804 - val_accuracy: 0.5112
# Epoch 67/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9776 - accuracy: 0.5215 - val_loss: 0.9800 - val_accuracy: 0.5112
# Epoch 68/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9773 - accuracy: 0.5215 - val_loss: 0.9798 - val_accuracy: 0.5112
# Epoch 69/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9770 - accuracy: 0.5215 - val_loss: 0.9796 - val_accuracy: 0.5112
# Epoch 70/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9768 - accuracy: 0.5215 - val_loss: 0.9794 - val_accuracy: 0.5112
# Epoch 71/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9766 - accuracy: 0.5215 - val_loss: 0.9792 - val_accuracy: 0.5112
# Epoch 72/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9763 - accuracy: 0.5215 - val_loss: 0.9790 - val_accuracy: 0.5112
# Epoch 73/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9762 - accuracy: 0.5215 - val_loss: 0.9787 - val_accuracy: 0.5112
# Epoch 74/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9759 - accuracy: 0.5215 - val_loss: 0.9785 - val_accuracy: 0.5112
# Epoch 75/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9758 - accuracy: 0.5215 - val_loss: 0.9783 - val_accuracy: 0.5112
# Epoch 76/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9756 - accuracy: 0.5215 - val_loss: 0.9781 - val_accuracy: 0.5112
# Epoch 77/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9754 - accuracy: 0.5215 - val_loss: 0.9780 - val_accuracy: 0.5112
# Epoch 78/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9752 - accuracy: 0.5215 - val_loss: 0.9778 - val_accuracy: 0.5112
# Epoch 79/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9751 - accuracy: 0.5215 - val_loss: 0.9776 - val_accuracy: 0.5112
# Epoch 80/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9749 - accuracy: 0.5215 - val_loss: 0.9774 - val_accuracy: 0.5112
# Epoch 81/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9747 - accuracy: 0.5215 - val_loss: 0.9772 - val_accuracy: 0.5112
# Epoch 82/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9745 - accuracy: 0.5215 - val_loss: 0.9771 - val_accuracy: 0.5112
# Epoch 83/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9744 - accuracy: 0.5215 - val_loss: 0.9770 - val_accuracy: 0.5112
# Epoch 84/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9743 - accuracy: 0.5215 - val_loss: 0.9769 - val_accuracy: 0.5112
# Epoch 85/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9742 - accuracy: 0.5215 - val_loss: 0.9767 - val_accuracy: 0.5112
# Epoch 86/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9741 - accuracy: 0.5215 - val_loss: 0.9766 - val_accuracy: 0.5112
# Epoch 87/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9739 - accuracy: 0.5215 - val_loss: 0.9766 - val_accuracy: 0.5112
# Epoch 88/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9738 - accuracy: 0.5215 - val_loss: 0.9764 - val_accuracy: 0.5112
# Epoch 89/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9737 - accuracy: 0.5215 - val_loss: 0.9762 - val_accuracy: 0.5112
# Epoch 90/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9735 - accuracy: 0.5215 - val_loss: 0.9761 - val_accuracy: 0.5112
# Epoch 91/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9734 - accuracy: 0.5215 - val_loss: 0.9761 - val_accuracy: 0.5112
# Epoch 92/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9733 - accuracy: 0.5215 - val_loss: 0.9759 - val_accuracy: 0.5112
# Epoch 93/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9732 - accuracy: 0.5215 - val_loss: 0.9758 - val_accuracy: 0.5112
# Epoch 94/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9731 - accuracy: 0.5215 - val_loss: 0.9757 - val_accuracy: 0.5112
# Epoch 95/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9730 - accuracy: 0.5215 - val_loss: 0.9756 - val_accuracy: 0.5112
# Epoch 96/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9730 - accuracy: 0.5215 - val_loss: 0.9755 - val_accuracy: 0.5112
# Epoch 97/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9729 - accuracy: 0.5215 - val_loss: 0.9755 - val_accuracy: 0.5112
# Epoch 98/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9729 - accuracy: 0.5215 - val_loss: 0.9754 - val_accuracy: 0.5112
# Epoch 99/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9728 - accuracy: 0.5215 - val_loss: 0.9755 - val_accuracy: 0.5112
# Epoch 100/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9728 - accuracy: 0.5215 - val_loss: 0.9754 - val_accuracy: 0.5112
# Epoch 101/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9727 - accuracy: 0.5215 - val_loss: 0.9753 - val_accuracy: 0.5112
# Epoch 102/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9726 - accuracy: 0.5215 - val_loss: 0.9752 - val_accuracy: 0.5112
# Epoch 103/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9726 - accuracy: 0.5215 - val_loss: 0.9752 - val_accuracy: 0.5112
# Epoch 104/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9725 - accuracy: 0.5215 - val_loss: 0.9751 - val_accuracy: 0.5112
# Epoch 105/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9725 - accuracy: 0.5215 - val_loss: 0.9751 - val_accuracy: 0.5112
# Epoch 106/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9724 - accuracy: 0.5215 - val_loss: 0.9750 - val_accuracy: 0.5112
# Epoch 107/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9724 - accuracy: 0.5215 - val_loss: 0.9749 - val_accuracy: 0.5112
# Epoch 108/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9723 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 109/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9722 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 110/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9722 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 111/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9721 - accuracy: 0.5215 - val_loss: 0.9749 - val_accuracy: 0.5112
# Epoch 112/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9721 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 113/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9721 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 114/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9720 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 115/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9720 - accuracy: 0.5215 - val_loss: 0.9746 - val_accuracy: 0.5112
# Epoch 116/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9720 - accuracy: 0.5215 - val_loss: 0.9746 - val_accuracy: 0.5112
# Epoch 117/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9746 - val_accuracy: 0.5112
# Epoch 118/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9745 - val_accuracy: 0.5112
# Epoch 119/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9746 - val_accuracy: 0.5112
# Epoch 120/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9745 - val_accuracy: 0.5112
# Epoch 121/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9744 - val_accuracy: 0.5112
# Epoch 122/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9743 - val_accuracy: 0.5112
# Epoch 123/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 124/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 125/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 126/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 127/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 128/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 129/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 130/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 131/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 132/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 133/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 134/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 135/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 136/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 137/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 138/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 139/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 140/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 141/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 142/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 143/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 144/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 145/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 146/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 147/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 148/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 149/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 150/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 151/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 152/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 153/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 154/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 155/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 156/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 157/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 158/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 159/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 160/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 161/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 162/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 163/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 164/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 165/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 166/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 167/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 168/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 169/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 170/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 171/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 172/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 173/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 174/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 175/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 176/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 177/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 178/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 179/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 180/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 181/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 182/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 183/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 184/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 185/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 186/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112
# Epoch 187/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 188/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 189/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 190/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112
# Epoch 191/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112
# Epoch 192/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112
# Epoch 193/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112
# Epoch 194/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9710 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112
# Epoch 195/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9731 - val_accuracy: 0.5112
# Epoch 196/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9731 - val_accuracy: 0.5112
# Epoch 197/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9731 - val_accuracy: 0.5112
# Epoch 198/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112
# Epoch 199/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112
# Epoch 200/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9710 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112

# %% [markdown]
# #### Evaluate your model training
# TensorFlow offers now (this was more cumbersome before) a simple history plotter that you can use to plot training histories and see how the model performed on training and validation data set.

# %%
training_history
# Out:
# {'firstmodel': <keras.callbacks.History at 0x2b8c1ae50>,
#  'second_model': <keras.callbacks.History at 0x2b8edffa0>,
#  'third_model': <keras.callbacks.History at 0x2b8ffef70>}

# %%
# Plotting function for MSE
def plot_metric(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

# %%
plot_metric(training_history['firstmodel'])

# %%
# Plotting function for loss
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.title('Model Loss')
    plt.ylim([0, 10])
    plt.xlabel('Epoch')
    plt.ylabel('Error')
    plt.legend()
    plt.grid(True)

# %%
plot_loss(training_history["firstmodel"])

# %%
history_plotter = tfdocs.plots.HistoryPlotter(metric = 'accuracy', smoothing_std=10)
history_plotter.plot(training_history)

# %% [markdown]
# ## Model tuning
# You might have no luck with your first model (most surely you did not). In this section you will apply methods you know to tune your model's performance. An obvious way of course is to change your model's architecture (removing or adding layers or layer dimensions, changing activation functions).
#
# However, after this you might still be able to detect some overfitting and there are some more methods you can apply to improve your neural network. Some of them are regularization, learning rate decay, early stopping, or dropout.
#
# If you want to add regularization you can apply directly layer-wise L2- or L1-regularization by using a layer's `kernel_regularization` argument and an appropriate regularizer from the [`tensorflow.keras.regularizers`](https://www.tensorflow.org/api_docs/python/tf/keras/regularizers) module we imported for you.
#
# __Optimizer schedules__<br>
# Quite often your optimizer does not run efficiently through the loss function surface. Remember that theory ensures a convergence of mini-batch SGD if and only if the learing rate decreases sufficiently fast. A way to apply this to your model training is to use a learning rate scheduler (learning rate decay) that reduces the learning rate over the number of update steps. The [`tf.keras.optimizers.schedules`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules) module offers you some approaches to do that.
#
# Note that to apply this to your `model_compile_and_fit()` function you defined above you need to implement the learning rate schedule either in there or with a helper function that your function calls inside.
#
# If you want to visualize different schedulers you can define them and call them on a range of values and plot them in a line plot.
#
# __Early stopping__<br>
# Earyl stopping is a procedure that enables you to stop your training earlier than defined by your `max_epochs` argument. It is used in practices to
# 1. determine the optimal parameter vector by monitoring the validation error closely (if it rises again too much stuck with the best parameters found until then) and
# 2. to save expensive resources (either in terms of monetary costs or ecological costs).
#
# To implement early stopping in TensorFlow the `tf.keras` module offers you a `callback` named [`tf.keras.callback.EarlyStopping()`](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping) that monitors for you a certain metric (it makes sense here to use a validation metric) and to stop training after a certain number of epochs with no improvement or by defining a certain `min_delta` that defines a minimum value of improvement - if below the callback stops your training.
#
# You can add this callback simply to the callbacks defined in your `get_callbacks()` function you defined above.
#
# __Dropout__<br>
# Dropout was one of the important developments in regularization for neural networks. It was developed by Geoffrey Hinton and his team at Toronto University.
#
# Dropout can be applied to each layer in your network and is implemented in `tf.keras` by an own layer named `Dropout()` awaiting a dropout rate set by you. So to introduce dropout you have to rework your model design.
#
# Make use of your knowledge and apply tuning techniques to improve your network.

# %%
#===========#
# Second Model with more nodes
#===========#

with tf.device('/cpu:0'):
    model = tf.keras.Sequential([
    tf.keras.layers.Dense(units = 36, kernel_initializer = 'uniform', activation = 'relu', input_dim = 368),
    tf.keras.layers.Dense(units = 36, kernel_initializer = 'uniform', activation = 'relu'),
    tf.keras.layers.Dense(units= 3,kernel_initializer = 'uniform', activation = 'softmax')
    ])  

#your_history = model_compile_and_fit(your_model, ....)
with tf.device('/cpu:0'):
    training_history["second_model"] = model_compile_and_fit(model, "second_model")
# Out:
# Epoch 1/200
# 9/9 [==============================] - 0s 12ms/step - loss: 1.0963 - accuracy: 0.4724 - val_loss: 1.0919 - val_accuracy: 0.5112
# Epoch 2/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0893 - accuracy: 0.5215 - val_loss: 1.0853 - val_accuracy: 0.5112
# Epoch 3/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0827 - accuracy: 0.5215 - val_loss: 1.0794 - val_accuracy: 0.5112
# Epoch 4/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0769 - accuracy: 0.5215 - val_loss: 1.0746 - val_accuracy: 0.5112
# Epoch 5/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0720 - accuracy: 0.5215 - val_loss: 1.0692 - val_accuracy: 0.5112
# Epoch 6/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0667 - accuracy: 0.5215 - val_loss: 1.0637 - val_accuracy: 0.5112
# Epoch 7/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0612 - accuracy: 0.5215 - val_loss: 1.0594 - val_accuracy: 0.5112
# Epoch 8/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0569 - accuracy: 0.5215 - val_loss: 1.0546 - val_accuracy: 0.5112
# Epoch 9/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0522 - accuracy: 0.5215 - val_loss: 1.0502 - val_accuracy: 0.5112
# Epoch 10/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0477 - accuracy: 0.5215 - val_loss: 1.0463 - val_accuracy: 0.5112
# Epoch 11/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0438 - accuracy: 0.5215 - val_loss: 1.0428 - val_accuracy: 0.5112
# Epoch 12/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0404 - accuracy: 0.5215 - val_loss: 1.0396 - val_accuracy: 0.5112
# Epoch 13/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0371 - accuracy: 0.5215 - val_loss: 1.0365 - val_accuracy: 0.5112
# Epoch 14/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0340 - accuracy: 0.5215 - val_loss: 1.0336 - val_accuracy: 0.5112
# Epoch 15/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0311 - accuracy: 0.5215 - val_loss: 1.0310 - val_accuracy: 0.5112
# Epoch 16/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0284 - accuracy: 0.5215 - val_loss: 1.0280 - val_accuracy: 0.5112
# Epoch 17/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0253 - accuracy: 0.5215 - val_loss: 1.0250 - val_accuracy: 0.5112
# Epoch 18/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0223 - accuracy: 0.5215 - val_loss: 1.0224 - val_accuracy: 0.5112
# Epoch 19/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0197 - accuracy: 0.5215 - val_loss: 1.0198 - val_accuracy: 0.5112
# Epoch 20/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0171 - accuracy: 0.5215 - val_loss: 1.0172 - val_accuracy: 0.5112
# Epoch 21/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0145 - accuracy: 0.5215 - val_loss: 1.0148 - val_accuracy: 0.5112
# Epoch 22/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0120 - accuracy: 0.5215 - val_loss: 1.0129 - val_accuracy: 0.5112
# Epoch 23/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0101 - accuracy: 0.5215 - val_loss: 1.0117 - val_accuracy: 0.5112
# Epoch 24/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0089 - accuracy: 0.5215 - val_loss: 1.0105 - val_accuracy: 0.5112
# Epoch 25/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0077 - accuracy: 0.5215 - val_loss: 1.0086 - val_accuracy: 0.5112
# Epoch 26/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0058 - accuracy: 0.5215 - val_loss: 1.0070 - val_accuracy: 0.5112
# Epoch 27/200
# 9/9 [==============================] - 0s 11ms/step - loss: 1.0042 - accuracy: 0.5215 - val_loss: 1.0055 - val_accuracy: 0.5112
# Epoch 28/200
# 9/9 [==============================] - 0s 12ms/step - loss: 1.0027 - accuracy: 0.5215 - val_loss: 1.0038 - val_accuracy: 0.5112
# Epoch 29/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0010 - accuracy: 0.5215 - val_loss: 1.0027 - val_accuracy: 0.5112
# Epoch 30/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9999 - accuracy: 0.5215 - val_loss: 1.0013 - val_accuracy: 0.5112
# Epoch 31/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9984 - accuracy: 0.5215 - val_loss: 0.9999 - val_accuracy: 0.5112
# Epoch 32/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9971 - accuracy: 0.5215 - val_loss: 0.9990 - val_accuracy: 0.5112
# Epoch 33/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9961 - accuracy: 0.5215 - val_loss: 0.9985 - val_accuracy: 0.5112
# Epoch 34/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9956 - accuracy: 0.5215 - val_loss: 0.9974 - val_accuracy: 0.5112
# Epoch 35/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9945 - accuracy: 0.5215 - val_loss: 0.9962 - val_accuracy: 0.5112
# Epoch 36/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9934 - accuracy: 0.5215 - val_loss: 0.9951 - val_accuracy: 0.5112
# Epoch 37/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9923 - accuracy: 0.5215 - val_loss: 0.9946 - val_accuracy: 0.5112
# Epoch 38/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9918 - accuracy: 0.5215 - val_loss: 0.9937 - val_accuracy: 0.5112
# Epoch 39/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9909 - accuracy: 0.5215 - val_loss: 0.9927 - val_accuracy: 0.5112
# Epoch 40/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9898 - accuracy: 0.5215 - val_loss: 0.9920 - val_accuracy: 0.5112
# Epoch 41/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9890 - accuracy: 0.5215 - val_loss: 0.9912 - val_accuracy: 0.5112
# Epoch 42/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9883 - accuracy: 0.5215 - val_loss: 0.9905 - val_accuracy: 0.5112
# Epoch 43/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9876 - accuracy: 0.5215 - val_loss: 0.9900 - val_accuracy: 0.5112
# Epoch 44/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9870 - accuracy: 0.5215 - val_loss: 0.9892 - val_accuracy: 0.5112
# Epoch 45/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9861 - accuracy: 0.5215 - val_loss: 0.9885 - val_accuracy: 0.5112
# Epoch 46/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9854 - accuracy: 0.5215 - val_loss: 0.9879 - val_accuracy: 0.5112
# Epoch 47/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9848 - accuracy: 0.5215 - val_loss: 0.9872 - val_accuracy: 0.5112
# Epoch 48/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9841 - accuracy: 0.5215 - val_loss: 0.9866 - val_accuracy: 0.5112
# Epoch 49/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9835 - accuracy: 0.5215 - val_loss: 0.9863 - val_accuracy: 0.5112
# Epoch 50/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9832 - accuracy: 0.5215 - val_loss: 0.9857 - val_accuracy: 0.5112
# Epoch 51/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9826 - accuracy: 0.5215 - val_loss: 0.9852 - val_accuracy: 0.5112
# Epoch 52/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9821 - accuracy: 0.5215 - val_loss: 0.9849 - val_accuracy: 0.5112
# Epoch 53/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9817 - accuracy: 0.5215 - val_loss: 0.9845 - val_accuracy: 0.5112
# Epoch 54/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9813 - accuracy: 0.5215 - val_loss: 0.9841 - val_accuracy: 0.5112
# Epoch 55/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9808 - accuracy: 0.5215 - val_loss: 0.9836 - val_accuracy: 0.5112
# Epoch 56/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9804 - accuracy: 0.5215 - val_loss: 0.9833 - val_accuracy: 0.5112
# Epoch 57/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9801 - accuracy: 0.5215 - val_loss: 0.9830 - val_accuracy: 0.5112
# Epoch 58/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9799 - accuracy: 0.5215 - val_loss: 0.9827 - val_accuracy: 0.5112
# Epoch 59/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9795 - accuracy: 0.5215 - val_loss: 0.9822 - val_accuracy: 0.5112
# Epoch 60/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9791 - accuracy: 0.5215 - val_loss: 0.9822 - val_accuracy: 0.5112
# Epoch 61/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9790 - accuracy: 0.5215 - val_loss: 0.9819 - val_accuracy: 0.5112
# Epoch 62/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9787 - accuracy: 0.5215 - val_loss: 0.9816 - val_accuracy: 0.5112
# Epoch 63/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9784 - accuracy: 0.5215 - val_loss: 0.9813 - val_accuracy: 0.5112
# Epoch 64/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9781 - accuracy: 0.5215 - val_loss: 0.9810 - val_accuracy: 0.5112
# Epoch 65/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9779 - accuracy: 0.5215 - val_loss: 0.9807 - val_accuracy: 0.5112
# Epoch 66/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9776 - accuracy: 0.5215 - val_loss: 0.9804 - val_accuracy: 0.5112
# Epoch 67/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9774 - accuracy: 0.5215 - val_loss: 0.9802 - val_accuracy: 0.5112
# Epoch 68/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9771 - accuracy: 0.5215 - val_loss: 0.9800 - val_accuracy: 0.5112
# Epoch 69/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9770 - accuracy: 0.5215 - val_loss: 0.9798 - val_accuracy: 0.5112
# Epoch 70/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9768 - accuracy: 0.5215 - val_loss: 0.9795 - val_accuracy: 0.5112
# Epoch 71/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9765 - accuracy: 0.5215 - val_loss: 0.9793 - val_accuracy: 0.5112
# Epoch 72/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9763 - accuracy: 0.5215 - val_loss: 0.9791 - val_accuracy: 0.5112
# Epoch 73/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9761 - accuracy: 0.5215 - val_loss: 0.9788 - val_accuracy: 0.5112
# Epoch 74/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9758 - accuracy: 0.5215 - val_loss: 0.9786 - val_accuracy: 0.5112
# Epoch 75/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9756 - accuracy: 0.5215 - val_loss: 0.9784 - val_accuracy: 0.5112
# Epoch 76/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9755 - accuracy: 0.5215 - val_loss: 0.9784 - val_accuracy: 0.5112
# Epoch 77/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9754 - accuracy: 0.5215 - val_loss: 0.9783 - val_accuracy: 0.5112
# Epoch 78/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9753 - accuracy: 0.5215 - val_loss: 0.9781 - val_accuracy: 0.5112
# Epoch 79/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9751 - accuracy: 0.5215 - val_loss: 0.9780 - val_accuracy: 0.5112
# Epoch 80/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9750 - accuracy: 0.5215 - val_loss: 0.9779 - val_accuracy: 0.5112
# Epoch 81/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9749 - accuracy: 0.5215 - val_loss: 0.9776 - val_accuracy: 0.5112
# Epoch 82/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9747 - accuracy: 0.5215 - val_loss: 0.9774 - val_accuracy: 0.5112
# Epoch 83/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9744 - accuracy: 0.5215 - val_loss: 0.9773 - val_accuracy: 0.5112
# Epoch 84/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9743 - accuracy: 0.5215 - val_loss: 0.9770 - val_accuracy: 0.5112
# Epoch 85/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9741 - accuracy: 0.5215 - val_loss: 0.9769 - val_accuracy: 0.5112
# Epoch 86/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9739 - accuracy: 0.5215 - val_loss: 0.9768 - val_accuracy: 0.5112
# Epoch 87/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9738 - accuracy: 0.5215 - val_loss: 0.9766 - val_accuracy: 0.5112
# Epoch 88/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9737 - accuracy: 0.5215 - val_loss: 0.9765 - val_accuracy: 0.5112
# Epoch 89/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9736 - accuracy: 0.5215 - val_loss: 0.9764 - val_accuracy: 0.5112
# Epoch 90/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9735 - accuracy: 0.5215 - val_loss: 0.9763 - val_accuracy: 0.5112
# Epoch 91/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9735 - accuracy: 0.5215 - val_loss: 0.9762 - val_accuracy: 0.5112
# Epoch 92/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9733 - accuracy: 0.5215 - val_loss: 0.9760 - val_accuracy: 0.5112
# Epoch 93/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9731 - accuracy: 0.5215 - val_loss: 0.9759 - val_accuracy: 0.5112
# Epoch 94/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9730 - accuracy: 0.5215 - val_loss: 0.9758 - val_accuracy: 0.5112
# Epoch 95/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9729 - accuracy: 0.5215 - val_loss: 0.9757 - val_accuracy: 0.5112
# Epoch 96/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9728 - accuracy: 0.5215 - val_loss: 0.9756 - val_accuracy: 0.5112
# Epoch 97/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9727 - accuracy: 0.5215 - val_loss: 0.9755 - val_accuracy: 0.5112
# Epoch 98/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9726 - accuracy: 0.5215 - val_loss: 0.9754 - val_accuracy: 0.5112
# Epoch 99/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9726 - accuracy: 0.5215 - val_loss: 0.9753 - val_accuracy: 0.5112
# Epoch 100/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9725 - accuracy: 0.5215 - val_loss: 0.9751 - val_accuracy: 0.5112
# Epoch 101/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9724 - accuracy: 0.5215 - val_loss: 0.9751 - val_accuracy: 0.5112
# Epoch 102/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9723 - accuracy: 0.5215 - val_loss: 0.9749 - val_accuracy: 0.5112
# Epoch 103/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9722 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 104/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9721 - accuracy: 0.5215 - val_loss: 0.9747 - val_accuracy: 0.5112
# Epoch 105/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9721 - accuracy: 0.5215 - val_loss: 0.9747 - val_accuracy: 0.5112
# Epoch 106/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9720 - accuracy: 0.5215 - val_loss: 0.9745 - val_accuracy: 0.5112
# Epoch 107/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9745 - val_accuracy: 0.5112
# Epoch 108/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9743 - val_accuracy: 0.5112
# Epoch 109/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 110/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 111/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 112/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 113/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 114/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 115/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 116/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 117/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 118/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 119/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 120/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 121/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 122/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 123/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 124/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 125/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9711 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 126/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9710 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 127/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9710 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 128/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9709 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 129/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9709 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 130/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9709 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 131/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9708 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112
# Epoch 132/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9708 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 133/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9708 - accuracy: 0.5215 - val_loss: 0.9732 - val_accuracy: 0.5112
# Epoch 134/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9708 - accuracy: 0.5215 - val_loss: 0.9731 - val_accuracy: 0.5112
# Epoch 135/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9707 - accuracy: 0.5215 - val_loss: 0.9731 - val_accuracy: 0.5112
# Epoch 136/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9707 - accuracy: 0.5215 - val_loss: 0.9731 - val_accuracy: 0.5112
# Epoch 137/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9706 - accuracy: 0.5215 - val_loss: 0.9730 - val_accuracy: 0.5112
# Epoch 138/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9706 - accuracy: 0.5215 - val_loss: 0.9731 - val_accuracy: 0.5112
# Epoch 139/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9706 - accuracy: 0.5215 - val_loss: 0.9731 - val_accuracy: 0.5112
# Epoch 140/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9706 - accuracy: 0.5215 - val_loss: 0.9730 - val_accuracy: 0.5112
# Epoch 141/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9706 - accuracy: 0.5215 - val_loss: 0.9730 - val_accuracy: 0.5112
# Epoch 142/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9705 - accuracy: 0.5215 - val_loss: 0.9730 - val_accuracy: 0.5112
# Epoch 143/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9705 - accuracy: 0.5215 - val_loss: 0.9730 - val_accuracy: 0.5112
# Epoch 144/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9705 - accuracy: 0.5215 - val_loss: 0.9729 - val_accuracy: 0.5112
# Epoch 145/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9704 - accuracy: 0.5215 - val_loss: 0.9729 - val_accuracy: 0.5112
# Epoch 146/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9704 - accuracy: 0.5215 - val_loss: 0.9727 - val_accuracy: 0.5112
# Epoch 147/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9704 - accuracy: 0.5215 - val_loss: 0.9727 - val_accuracy: 0.5112
# Epoch 148/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9703 - accuracy: 0.5215 - val_loss: 0.9727 - val_accuracy: 0.5112
# Epoch 149/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9704 - accuracy: 0.5215 - val_loss: 0.9726 - val_accuracy: 0.5112
# Epoch 150/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9703 - accuracy: 0.5215 - val_loss: 0.9726 - val_accuracy: 0.5112
# Epoch 151/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9703 - accuracy: 0.5215 - val_loss: 0.9726 - val_accuracy: 0.5112
# Epoch 152/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9703 - accuracy: 0.5215 - val_loss: 0.9726 - val_accuracy: 0.5112
# Epoch 153/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9703 - accuracy: 0.5215 - val_loss: 0.9726 - val_accuracy: 0.5112
# Epoch 154/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9703 - accuracy: 0.5215 - val_loss: 0.9725 - val_accuracy: 0.5112
# Epoch 155/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9702 - accuracy: 0.5215 - val_loss: 0.9726 - val_accuracy: 0.5112
# Epoch 156/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9702 - accuracy: 0.5215 - val_loss: 0.9725 - val_accuracy: 0.5112
# Epoch 157/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9702 - accuracy: 0.5215 - val_loss: 0.9725 - val_accuracy: 0.5112
# Epoch 158/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9702 - accuracy: 0.5215 - val_loss: 0.9724 - val_accuracy: 0.5112
# Epoch 159/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9701 - accuracy: 0.5215 - val_loss: 0.9724 - val_accuracy: 0.5112
# Epoch 160/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9701 - accuracy: 0.5215 - val_loss: 0.9725 - val_accuracy: 0.5112
# Epoch 161/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9701 - accuracy: 0.5215 - val_loss: 0.9724 - val_accuracy: 0.5112
# Epoch 162/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9701 - accuracy: 0.5215 - val_loss: 0.9725 - val_accuracy: 0.5112
# Epoch 163/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9700 - accuracy: 0.5215 - val_loss: 0.9725 - val_accuracy: 0.5112
# Epoch 164/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9700 - accuracy: 0.5215 - val_loss: 0.9724 - val_accuracy: 0.5112
# Epoch 165/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9700 - accuracy: 0.5215 - val_loss: 0.9724 - val_accuracy: 0.5112
# Epoch 166/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9700 - accuracy: 0.5215 - val_loss: 0.9723 - val_accuracy: 0.5112
# Epoch 167/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9699 - accuracy: 0.5215 - val_loss: 0.9723 - val_accuracy: 0.5112
# Epoch 168/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9699 - accuracy: 0.5215 - val_loss: 0.9723 - val_accuracy: 0.5112
# Epoch 169/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9699 - accuracy: 0.5215 - val_loss: 0.9722 - val_accuracy: 0.5112
# Epoch 170/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9699 - accuracy: 0.5215 - val_loss: 0.9722 - val_accuracy: 0.5112
# Epoch 171/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9699 - accuracy: 0.5215 - val_loss: 0.9722 - val_accuracy: 0.5112
# Epoch 172/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9698 - accuracy: 0.5215 - val_loss: 0.9721 - val_accuracy: 0.5112
# Epoch 173/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9698 - accuracy: 0.5215 - val_loss: 0.9721 - val_accuracy: 0.5112
# Epoch 174/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9698 - accuracy: 0.5215 - val_loss: 0.9720 - val_accuracy: 0.5112
# Epoch 175/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9698 - accuracy: 0.5215 - val_loss: 0.9721 - val_accuracy: 0.5112
# Epoch 176/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9697 - accuracy: 0.5215 - val_loss: 0.9720 - val_accuracy: 0.5112
# Epoch 177/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9697 - accuracy: 0.5215 - val_loss: 0.9720 - val_accuracy: 0.5112
# Epoch 178/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9697 - accuracy: 0.5215 - val_loss: 0.9720 - val_accuracy: 0.5112
# Epoch 179/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9697 - accuracy: 0.5215 - val_loss: 0.9719 - val_accuracy: 0.5112
# Epoch 180/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9696 - accuracy: 0.5215 - val_loss: 0.9718 - val_accuracy: 0.5112
# Epoch 181/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9696 - accuracy: 0.5215 - val_loss: 0.9718 - val_accuracy: 0.5112
# Epoch 182/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9696 - accuracy: 0.5215 - val_loss: 0.9718 - val_accuracy: 0.5112
# Epoch 183/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9696 - accuracy: 0.5215 - val_loss: 0.9717 - val_accuracy: 0.5112
# Epoch 184/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9696 - accuracy: 0.5215 - val_loss: 0.9718 - val_accuracy: 0.5112
# Epoch 185/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9695 - accuracy: 0.5215 - val_loss: 0.9717 - val_accuracy: 0.5112
# Epoch 186/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9695 - accuracy: 0.5215 - val_loss: 0.9717 - val_accuracy: 0.5112
# Epoch 187/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9695 - accuracy: 0.5215 - val_loss: 0.9718 - val_accuracy: 0.5112
# Epoch 188/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9695 - accuracy: 0.5215 - val_loss: 0.9717 - val_accuracy: 0.5112
# Epoch 189/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9694 - accuracy: 0.5215 - val_loss: 0.9717 - val_accuracy: 0.5112
# Epoch 190/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9694 - accuracy: 0.5215 - val_loss: 0.9717 - val_accuracy: 0.5112
# Epoch 191/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9694 - accuracy: 0.5215 - val_loss: 0.9716 - val_accuracy: 0.5112
# Epoch 192/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9694 - accuracy: 0.5215 - val_loss: 0.9717 - val_accuracy: 0.5112
# Epoch 193/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9694 - accuracy: 0.5215 - val_loss: 0.9717 - val_accuracy: 0.5112
# Epoch 194/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9694 - accuracy: 0.5215 - val_loss: 0.9716 - val_accuracy: 0.5112
# Epoch 195/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9694 - accuracy: 0.5215 - val_loss: 0.9717 - val_accuracy: 0.5112
# Epoch 196/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9694 - accuracy: 0.5215 - val_loss: 0.9716 - val_accuracy: 0.5112
# Epoch 197/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9693 - accuracy: 0.5215 - val_loss: 0.9716 - val_accuracy: 0.5112
# Epoch 198/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9693 - accuracy: 0.5215 - val_loss: 0.9716 - val_accuracy: 0.5112
# Epoch 199/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9693 - accuracy: 0.5215 - val_loss: 0.9716 - val_accuracy: 0.5112
# Epoch 200/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9693 - accuracy: 0.5215 - val_loss: 0.9715 - val_accuracy: 0.5112

# %%
plot_metric(training_history['second_model'])

# %%
history_plotter = tfdocs.plots.HistoryPlotter(metric = 'accuracy', smoothing_std=10)
history_plotter.plot(training_history)

# %%
#===========#
# Third Model with more layers
#===========#

with tf.device('/cpu:0'):
    model = tf.keras.Sequential([
    tf.keras.layers.Dense(units = 36, kernel_initializer = 'uniform', activation = 'relu', input_dim = 368),
    tf.keras.layers.Dense(units = 36, kernel_initializer = 'uniform', activation = 'relu'),
    tf.keras.layers.Dense(units = 36, kernel_initializer = 'uniform', activation = 'relu'),
    tf.keras.layers.Dense(units = 36, kernel_initializer = 'uniform', activation = 'relu'),
    tf.keras.layers.Dense(units= 3,kernel_initializer = 'uniform', activation = 'softmax')
    ])  

#your_history = model_compile_and_fit(your_model, ....)
with tf.device('/cpu:0'):
    training_history["third_model"] = model_compile_and_fit(model, "third_model")
# Out:
# Epoch 1/200
# 9/9 [==============================] - 0s 14ms/step - loss: 1.0959 - accuracy: 0.5054 - val_loss: 1.0917 - val_accuracy: 0.5112
# Epoch 2/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0891 - accuracy: 0.5215 - val_loss: 1.0858 - val_accuracy: 0.5112
# Epoch 3/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0832 - accuracy: 0.5215 - val_loss: 1.0793 - val_accuracy: 0.5112
# Epoch 4/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0767 - accuracy: 0.5215 - val_loss: 1.0731 - val_accuracy: 0.5112
# Epoch 5/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0705 - accuracy: 0.5215 - val_loss: 1.0677 - val_accuracy: 0.5112
# Epoch 6/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0651 - accuracy: 0.5215 - val_loss: 1.0627 - val_accuracy: 0.5112
# Epoch 7/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0602 - accuracy: 0.5215 - val_loss: 1.0586 - val_accuracy: 0.5112
# Epoch 8/200
# 9/9 [==============================] - 0s 10ms/step - loss: 1.0561 - accuracy: 0.5215 - val_loss: 1.0539 - val_accuracy: 0.5112
# Epoch 9/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0514 - accuracy: 0.5215 - val_loss: 1.0500 - val_accuracy: 0.5112
# Epoch 10/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0474 - accuracy: 0.5215 - val_loss: 1.0462 - val_accuracy: 0.5112
# Epoch 11/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0437 - accuracy: 0.5215 - val_loss: 1.0427 - val_accuracy: 0.5112
# Epoch 12/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0402 - accuracy: 0.5215 - val_loss: 1.0389 - val_accuracy: 0.5112
# Epoch 13/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0364 - accuracy: 0.5215 - val_loss: 1.0358 - val_accuracy: 0.5112
# Epoch 14/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0332 - accuracy: 0.5215 - val_loss: 1.0324 - val_accuracy: 0.5112
# Epoch 15/200
# 9/9 [==============================] - 0s 13ms/step - loss: 1.0299 - accuracy: 0.5215 - val_loss: 1.0293 - val_accuracy: 0.5112
# Epoch 16/200
# 9/9 [==============================] - 0s 10ms/step - loss: 1.0268 - accuracy: 0.5215 - val_loss: 1.0265 - val_accuracy: 0.5112
# Epoch 17/200
# 9/9 [==============================] - 0s 9ms/step - loss: 1.0239 - accuracy: 0.5215 - val_loss: 1.0239 - val_accuracy: 0.5112
# Epoch 18/200
# 9/9 [==============================] - 0s 10ms/step - loss: 1.0213 - accuracy: 0.5215 - val_loss: 1.0215 - val_accuracy: 0.5112
# Epoch 19/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0190 - accuracy: 0.5215 - val_loss: 1.0190 - val_accuracy: 0.5112
# Epoch 20/200
# 9/9 [==============================] - 0s 11ms/step - loss: 1.0164 - accuracy: 0.5215 - val_loss: 1.0165 - val_accuracy: 0.5112
# Epoch 21/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0139 - accuracy: 0.5215 - val_loss: 1.0143 - val_accuracy: 0.5112
# Epoch 22/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0117 - accuracy: 0.5215 - val_loss: 1.0125 - val_accuracy: 0.5112
# Epoch 23/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0100 - accuracy: 0.5215 - val_loss: 1.0108 - val_accuracy: 0.5112
# Epoch 24/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0083 - accuracy: 0.5215 - val_loss: 1.0092 - val_accuracy: 0.5112
# Epoch 25/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0067 - accuracy: 0.5215 - val_loss: 1.0073 - val_accuracy: 0.5112
# Epoch 26/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0048 - accuracy: 0.5215 - val_loss: 1.0054 - val_accuracy: 0.5112
# Epoch 27/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0029 - accuracy: 0.5215 - val_loss: 1.0041 - val_accuracy: 0.5112
# Epoch 28/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0016 - accuracy: 0.5215 - val_loss: 1.0029 - val_accuracy: 0.5112
# Epoch 29/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0004 - accuracy: 0.5215 - val_loss: 1.0014 - val_accuracy: 0.5112
# Epoch 30/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9990 - accuracy: 0.5215 - val_loss: 1.0003 - val_accuracy: 0.5112
# Epoch 31/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9978 - accuracy: 0.5215 - val_loss: 0.9993 - val_accuracy: 0.5112
# Epoch 32/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9968 - accuracy: 0.5215 - val_loss: 0.9981 - val_accuracy: 0.5112
# Epoch 33/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9955 - accuracy: 0.5215 - val_loss: 0.9968 - val_accuracy: 0.5112
# Epoch 34/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9943 - accuracy: 0.5215 - val_loss: 0.9956 - val_accuracy: 0.5112
# Epoch 35/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9929 - accuracy: 0.5215 - val_loss: 0.9946 - val_accuracy: 0.5112
# Epoch 36/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9919 - accuracy: 0.5215 - val_loss: 0.9938 - val_accuracy: 0.5112
# Epoch 37/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9911 - accuracy: 0.5215 - val_loss: 0.9928 - val_accuracy: 0.5112
# Epoch 38/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9902 - accuracy: 0.5215 - val_loss: 0.9921 - val_accuracy: 0.5112
# Epoch 39/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9895 - accuracy: 0.5215 - val_loss: 0.9911 - val_accuracy: 0.5112
# Epoch 40/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9885 - accuracy: 0.5215 - val_loss: 0.9904 - val_accuracy: 0.5112
# Epoch 41/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9877 - accuracy: 0.5215 - val_loss: 0.9897 - val_accuracy: 0.5112
# Epoch 42/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9871 - accuracy: 0.5215 - val_loss: 0.9889 - val_accuracy: 0.5112
# Epoch 43/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9862 - accuracy: 0.5215 - val_loss: 0.9882 - val_accuracy: 0.5112
# Epoch 44/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9855 - accuracy: 0.5215 - val_loss: 0.9876 - val_accuracy: 0.5112
# Epoch 45/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9850 - accuracy: 0.5215 - val_loss: 0.9869 - val_accuracy: 0.5112
# Epoch 46/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9843 - accuracy: 0.5215 - val_loss: 0.9865 - val_accuracy: 0.5112
# Epoch 47/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9838 - accuracy: 0.5215 - val_loss: 0.9859 - val_accuracy: 0.5112
# Epoch 48/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9832 - accuracy: 0.5215 - val_loss: 0.9855 - val_accuracy: 0.5112
# Epoch 49/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9829 - accuracy: 0.5215 - val_loss: 0.9851 - val_accuracy: 0.5112
# Epoch 50/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9824 - accuracy: 0.5215 - val_loss: 0.9846 - val_accuracy: 0.5112
# Epoch 51/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9819 - accuracy: 0.5215 - val_loss: 0.9841 - val_accuracy: 0.5112
# Epoch 52/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9814 - accuracy: 0.5215 - val_loss: 0.9837 - val_accuracy: 0.5112
# Epoch 53/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9810 - accuracy: 0.5215 - val_loss: 0.9833 - val_accuracy: 0.5112
# Epoch 54/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9806 - accuracy: 0.5215 - val_loss: 0.9829 - val_accuracy: 0.5112
# Epoch 55/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9802 - accuracy: 0.5215 - val_loss: 0.9825 - val_accuracy: 0.5112
# Epoch 56/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9799 - accuracy: 0.5215 - val_loss: 0.9822 - val_accuracy: 0.5112
# Epoch 57/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9796 - accuracy: 0.5215 - val_loss: 0.9819 - val_accuracy: 0.5112
# Epoch 58/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9793 - accuracy: 0.5215 - val_loss: 0.9817 - val_accuracy: 0.5112
# Epoch 59/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9790 - accuracy: 0.5215 - val_loss: 0.9813 - val_accuracy: 0.5112
# Epoch 60/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9786 - accuracy: 0.5215 - val_loss: 0.9811 - val_accuracy: 0.5112
# Epoch 61/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9785 - accuracy: 0.5215 - val_loss: 0.9808 - val_accuracy: 0.5112
# Epoch 62/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9782 - accuracy: 0.5215 - val_loss: 0.9809 - val_accuracy: 0.5112
# Epoch 63/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9783 - accuracy: 0.5215 - val_loss: 0.9806 - val_accuracy: 0.5112
# Epoch 64/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9780 - accuracy: 0.5215 - val_loss: 0.9806 - val_accuracy: 0.5112
# Epoch 65/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9780 - accuracy: 0.5215 - val_loss: 0.9804 - val_accuracy: 0.5112
# Epoch 66/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9777 - accuracy: 0.5215 - val_loss: 0.9801 - val_accuracy: 0.5112
# Epoch 67/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9774 - accuracy: 0.5215 - val_loss: 0.9799 - val_accuracy: 0.5112
# Epoch 68/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9772 - accuracy: 0.5215 - val_loss: 0.9796 - val_accuracy: 0.5112
# Epoch 69/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9769 - accuracy: 0.5215 - val_loss: 0.9793 - val_accuracy: 0.5112
# Epoch 70/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9766 - accuracy: 0.5215 - val_loss: 0.9791 - val_accuracy: 0.5112
# Epoch 71/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9765 - accuracy: 0.5215 - val_loss: 0.9789 - val_accuracy: 0.5112
# Epoch 72/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9763 - accuracy: 0.5215 - val_loss: 0.9788 - val_accuracy: 0.5112
# Epoch 73/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9760 - accuracy: 0.5215 - val_loss: 0.9786 - val_accuracy: 0.5112
# Epoch 74/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9759 - accuracy: 0.5215 - val_loss: 0.9783 - val_accuracy: 0.5112
# Epoch 75/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9756 - accuracy: 0.5215 - val_loss: 0.9781 - val_accuracy: 0.5112
# Epoch 76/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9754 - accuracy: 0.5215 - val_loss: 0.9779 - val_accuracy: 0.5112
# Epoch 77/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9752 - accuracy: 0.5215 - val_loss: 0.9776 - val_accuracy: 0.5112
# Epoch 78/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9750 - accuracy: 0.5215 - val_loss: 0.9774 - val_accuracy: 0.5112
# Epoch 79/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9748 - accuracy: 0.5215 - val_loss: 0.9773 - val_accuracy: 0.5112
# Epoch 80/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9748 - accuracy: 0.5215 - val_loss: 0.9772 - val_accuracy: 0.5112
# Epoch 81/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9746 - accuracy: 0.5215 - val_loss: 0.9770 - val_accuracy: 0.5112
# Epoch 82/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9744 - accuracy: 0.5215 - val_loss: 0.9769 - val_accuracy: 0.5112
# Epoch 83/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9744 - accuracy: 0.5215 - val_loss: 0.9768 - val_accuracy: 0.5112
# Epoch 84/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9743 - accuracy: 0.5215 - val_loss: 0.9768 - val_accuracy: 0.5112
# Epoch 85/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9743 - accuracy: 0.5215 - val_loss: 0.9768 - val_accuracy: 0.5112
# Epoch 86/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9743 - accuracy: 0.5215 - val_loss: 0.9768 - val_accuracy: 0.5112
# Epoch 87/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9743 - accuracy: 0.5215 - val_loss: 0.9767 - val_accuracy: 0.5112
# Epoch 88/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9741 - accuracy: 0.5215 - val_loss: 0.9768 - val_accuracy: 0.5112
# Epoch 89/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9741 - accuracy: 0.5215 - val_loss: 0.9766 - val_accuracy: 0.5112
# Epoch 90/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9739 - accuracy: 0.5215 - val_loss: 0.9765 - val_accuracy: 0.5112
# Epoch 91/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9739 - accuracy: 0.5215 - val_loss: 0.9766 - val_accuracy: 0.5112
# Epoch 92/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9739 - accuracy: 0.5215 - val_loss: 0.9765 - val_accuracy: 0.5112
# Epoch 93/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9738 - accuracy: 0.5215 - val_loss: 0.9764 - val_accuracy: 0.5112
# Epoch 94/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9737 - accuracy: 0.5215 - val_loss: 0.9763 - val_accuracy: 0.5112
# Epoch 95/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9736 - accuracy: 0.5215 - val_loss: 0.9761 - val_accuracy: 0.5112
# Epoch 96/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9735 - accuracy: 0.5215 - val_loss: 0.9761 - val_accuracy: 0.5112
# Epoch 97/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9734 - accuracy: 0.5215 - val_loss: 0.9760 - val_accuracy: 0.5112
# Epoch 98/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9734 - accuracy: 0.5215 - val_loss: 0.9759 - val_accuracy: 0.5112
# Epoch 99/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9733 - accuracy: 0.5215 - val_loss: 0.9758 - val_accuracy: 0.5112
# Epoch 100/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9732 - accuracy: 0.5215 - val_loss: 0.9758 - val_accuracy: 0.5112
# Epoch 101/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9732 - accuracy: 0.5215 - val_loss: 0.9757 - val_accuracy: 0.5112
# Epoch 102/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9731 - accuracy: 0.5215 - val_loss: 0.9756 - val_accuracy: 0.5112
# Epoch 103/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9730 - accuracy: 0.5215 - val_loss: 0.9756 - val_accuracy: 0.5112
# Epoch 104/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9730 - accuracy: 0.5215 - val_loss: 0.9756 - val_accuracy: 0.5112
# Epoch 105/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9730 - accuracy: 0.5215 - val_loss: 0.9755 - val_accuracy: 0.5112
# Epoch 106/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9730 - accuracy: 0.5215 - val_loss: 0.9755 - val_accuracy: 0.5112
# Epoch 107/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9730 - accuracy: 0.5215 - val_loss: 0.9754 - val_accuracy: 0.5112
# Epoch 108/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9729 - accuracy: 0.5215 - val_loss: 0.9753 - val_accuracy: 0.5112
# Epoch 109/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9728 - accuracy: 0.5215 - val_loss: 0.9752 - val_accuracy: 0.5112
# Epoch 110/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9727 - accuracy: 0.5215 - val_loss: 0.9751 - val_accuracy: 0.5112
# Epoch 111/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9726 - accuracy: 0.5215 - val_loss: 0.9751 - val_accuracy: 0.5112
# Epoch 112/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9725 - accuracy: 0.5215 - val_loss: 0.9750 - val_accuracy: 0.5112
# Epoch 113/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9724 - accuracy: 0.5215 - val_loss: 0.9750 - val_accuracy: 0.5112
# Epoch 114/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9724 - accuracy: 0.5215 - val_loss: 0.9750 - val_accuracy: 0.5112
# Epoch 115/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9724 - accuracy: 0.5215 - val_loss: 0.9749 - val_accuracy: 0.5112
# Epoch 116/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9723 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 117/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9723 - accuracy: 0.5215 - val_loss: 0.9747 - val_accuracy: 0.5112
# Epoch 118/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9722 - accuracy: 0.5215 - val_loss: 0.9747 - val_accuracy: 0.5112
# Epoch 119/200
# 9/9 [==============================] - 0s 16ms/step - loss: 0.9722 - accuracy: 0.5215 - val_loss: 0.9746 - val_accuracy: 0.5112
# Epoch 120/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9721 - accuracy: 0.5215 - val_loss: 0.9745 - val_accuracy: 0.5112
# Epoch 121/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9721 - accuracy: 0.5215 - val_loss: 0.9745 - val_accuracy: 0.5112
# Epoch 122/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9720 - accuracy: 0.5215 - val_loss: 0.9745 - val_accuracy: 0.5112
# Epoch 123/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9720 - accuracy: 0.5215 - val_loss: 0.9744 - val_accuracy: 0.5112
# Epoch 124/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9720 - accuracy: 0.5215 - val_loss: 0.9744 - val_accuracy: 0.5112
# Epoch 125/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9743 - val_accuracy: 0.5112
# Epoch 126/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9743 - val_accuracy: 0.5112
# Epoch 127/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9743 - val_accuracy: 0.5112
# Epoch 128/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 129/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 130/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 131/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 132/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 133/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 134/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 135/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 136/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 137/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 138/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 139/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 140/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 141/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 142/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 143/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 144/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 145/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 146/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 147/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 148/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 149/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 150/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 151/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 152/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 153/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 154/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 155/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 156/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 157/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 158/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 159/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 160/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 161/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 162/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 163/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 164/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 165/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 166/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 167/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 168/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 169/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 170/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 171/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 172/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 173/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 174/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 175/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 176/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 177/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 178/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 179/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 180/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 181/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 182/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 183/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 184/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 185/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 186/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 187/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 188/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 189/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 190/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 191/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 192/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 193/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 194/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 195/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 196/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 197/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 198/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 199/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 200/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112

# %%
plot_metric(training_history['third_model'])

# %%
history_plotter = tfdocs.plots.HistoryPlotter(metric = 'accuracy', smoothing_std=10)
history_plotter.plot(training_history)

# %%
training_history
# Out:
# {'firstmodel': <keras.callbacks.History at 0x2b8c1ae50>,
#  'second_model': <keras.callbacks.History at 0x2b8edffa0>,
#  'third_model': <keras.callbacks.History at 0x2b8ffef70>}

# %%
# Instantiate HistoryPlotter
plotter = tfdocs.plots.HistoryPlotter(metric = 'accuracy', smoothing_std=10)

# %%
plotter.plot(training_history)
plt.xlim([5, max(plt.xlim())])
plt.ylim([0, 50])
plt.xlabel('Epochs')
plt.title('Comparison of all models')
plt.legend(loc='upper right');

# %%
#===========#
# Fourth Model with more layers
#===========#

with tf.device('/cpu:0'):
    model = tf.keras.Sequential([
    tf.keras.layers.Dense(units = 36, kernel_initializer = 'uniform', activation = 'relu', input_dim = 368),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(units = 36, kernel_initializer = 'uniform', activation = 'relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(units = 36, kernel_initializer = 'uniform', activation = 'relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(units = 36, kernel_initializer = 'uniform', activation = 'relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(units= 3,kernel_initializer = 'uniform', activation = 'softmax')
    ])  

#your_history = model_compile_and_fit(your_model, ....)
with tf.device('/cpu:0'):
    training_history["fourth_model"] = model_compile_and_fit(model, "fourth_model")
# Out:
# Epoch 1/200
# 9/9 [==============================] - 0s 16ms/step - loss: 1.0959 - accuracy: 0.4859 - val_loss: 1.0913 - val_accuracy: 0.5112
# Epoch 2/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0887 - accuracy: 0.5215 - val_loss: 1.0848 - val_accuracy: 0.5112
# Epoch 3/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0821 - accuracy: 0.5215 - val_loss: 1.0791 - val_accuracy: 0.5112
# Epoch 4/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0765 - accuracy: 0.5215 - val_loss: 1.0734 - val_accuracy: 0.5112
# Epoch 5/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0707 - accuracy: 0.5215 - val_loss: 1.0686 - val_accuracy: 0.5112
# Epoch 6/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0659 - accuracy: 0.5215 - val_loss: 1.0634 - val_accuracy: 0.5112
# Epoch 7/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0608 - accuracy: 0.5215 - val_loss: 1.0598 - val_accuracy: 0.5112
# Epoch 8/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0572 - accuracy: 0.5215 - val_loss: 1.0551 - val_accuracy: 0.5112
# Epoch 9/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0525 - accuracy: 0.5215 - val_loss: 1.0511 - val_accuracy: 0.5112
# Epoch 10/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0485 - accuracy: 0.5215 - val_loss: 1.0468 - val_accuracy: 0.5112
# Epoch 11/200
# 9/9 [==============================] - 0s 13ms/step - loss: 1.0441 - accuracy: 0.5215 - val_loss: 1.0432 - val_accuracy: 0.5112
# Epoch 12/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0406 - accuracy: 0.5215 - val_loss: 1.0398 - val_accuracy: 0.5112
# Epoch 13/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0372 - accuracy: 0.5215 - val_loss: 1.0361 - val_accuracy: 0.5112
# Epoch 14/200
# 9/9 [==============================] - 0s 9ms/step - loss: 1.0335 - accuracy: 0.5215 - val_loss: 1.0333 - val_accuracy: 0.5112
# Epoch 15/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0306 - accuracy: 0.5215 - val_loss: 1.0302 - val_accuracy: 0.5112
# Epoch 16/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0275 - accuracy: 0.5215 - val_loss: 1.0276 - val_accuracy: 0.5112
# Epoch 17/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0249 - accuracy: 0.5215 - val_loss: 1.0246 - val_accuracy: 0.5112
# Epoch 18/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0219 - accuracy: 0.5215 - val_loss: 1.0221 - val_accuracy: 0.5112
# Epoch 19/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0193 - accuracy: 0.5215 - val_loss: 1.0196 - val_accuracy: 0.5112
# Epoch 20/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0168 - accuracy: 0.5215 - val_loss: 1.0174 - val_accuracy: 0.5112
# Epoch 21/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0146 - accuracy: 0.5215 - val_loss: 1.0157 - val_accuracy: 0.5112
# Epoch 22/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0129 - accuracy: 0.5215 - val_loss: 1.0140 - val_accuracy: 0.5112
# Epoch 23/200
# 9/9 [==============================] - 0s 9ms/step - loss: 1.0111 - accuracy: 0.5215 - val_loss: 1.0119 - val_accuracy: 0.5112
# Epoch 24/200
# 9/9 [==============================] - 0s 12ms/step - loss: 1.0090 - accuracy: 0.5215 - val_loss: 1.0101 - val_accuracy: 0.5112
# Epoch 25/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0072 - accuracy: 0.5215 - val_loss: 1.0082 - val_accuracy: 0.5112
# Epoch 26/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0052 - accuracy: 0.5215 - val_loss: 1.0066 - val_accuracy: 0.5112
# Epoch 27/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0037 - accuracy: 0.5215 - val_loss: 1.0053 - val_accuracy: 0.5112
# Epoch 28/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0024 - accuracy: 0.5215 - val_loss: 1.0038 - val_accuracy: 0.5112
# Epoch 29/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0010 - accuracy: 0.5215 - val_loss: 1.0026 - val_accuracy: 0.5112
# Epoch 30/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9997 - accuracy: 0.5215 - val_loss: 1.0011 - val_accuracy: 0.5112
# Epoch 31/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9982 - accuracy: 0.5215 - val_loss: 0.9997 - val_accuracy: 0.5112
# Epoch 32/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9968 - accuracy: 0.5215 - val_loss: 0.9985 - val_accuracy: 0.5112
# Epoch 33/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9957 - accuracy: 0.5215 - val_loss: 0.9976 - val_accuracy: 0.5112
# Epoch 34/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9947 - accuracy: 0.5215 - val_loss: 0.9964 - val_accuracy: 0.5112
# Epoch 35/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9935 - accuracy: 0.5215 - val_loss: 0.9955 - val_accuracy: 0.5112
# Epoch 36/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9926 - accuracy: 0.5215 - val_loss: 0.9946 - val_accuracy: 0.5112
# Epoch 37/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.9917 - accuracy: 0.5215 - val_loss: 0.9937 - val_accuracy: 0.5112
# Epoch 38/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9908 - accuracy: 0.5215 - val_loss: 0.9929 - val_accuracy: 0.5112
# Epoch 39/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9900 - accuracy: 0.5215 - val_loss: 0.9921 - val_accuracy: 0.5112
# Epoch 40/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9892 - accuracy: 0.5215 - val_loss: 0.9913 - val_accuracy: 0.5112
# Epoch 41/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9883 - accuracy: 0.5215 - val_loss: 0.9904 - val_accuracy: 0.5112
# Epoch 42/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9874 - accuracy: 0.5215 - val_loss: 0.9898 - val_accuracy: 0.5112
# Epoch 43/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9867 - accuracy: 0.5215 - val_loss: 0.9892 - val_accuracy: 0.5112
# Epoch 44/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9862 - accuracy: 0.5215 - val_loss: 0.9886 - val_accuracy: 0.5112
# Epoch 45/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9856 - accuracy: 0.5215 - val_loss: 0.9880 - val_accuracy: 0.5112
# Epoch 46/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9850 - accuracy: 0.5215 - val_loss: 0.9875 - val_accuracy: 0.5112
# Epoch 47/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9845 - accuracy: 0.5215 - val_loss: 0.9869 - val_accuracy: 0.5112
# Epoch 48/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9840 - accuracy: 0.5215 - val_loss: 0.9865 - val_accuracy: 0.5112
# Epoch 49/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9834 - accuracy: 0.5215 - val_loss: 0.9860 - val_accuracy: 0.5112
# Epoch 50/200
# 9/9 [==============================] - 0s 14ms/step - loss: 0.9829 - accuracy: 0.5215 - val_loss: 0.9857 - val_accuracy: 0.5112
# Epoch 51/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9826 - accuracy: 0.5215 - val_loss: 0.9851 - val_accuracy: 0.5112
# Epoch 52/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9821 - accuracy: 0.5215 - val_loss: 0.9850 - val_accuracy: 0.5112
# Epoch 53/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9819 - accuracy: 0.5215 - val_loss: 0.9845 - val_accuracy: 0.5112
# Epoch 54/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9815 - accuracy: 0.5215 - val_loss: 0.9841 - val_accuracy: 0.5112
# Epoch 55/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9811 - accuracy: 0.5215 - val_loss: 0.9836 - val_accuracy: 0.5112
# Epoch 56/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9807 - accuracy: 0.5215 - val_loss: 0.9833 - val_accuracy: 0.5112
# Epoch 57/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9803 - accuracy: 0.5215 - val_loss: 0.9830 - val_accuracy: 0.5112
# Epoch 58/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.9799 - accuracy: 0.5215 - val_loss: 0.9827 - val_accuracy: 0.5112
# Epoch 59/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9796 - accuracy: 0.5215 - val_loss: 0.9823 - val_accuracy: 0.5112
# Epoch 60/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9793 - accuracy: 0.5215 - val_loss: 0.9820 - val_accuracy: 0.5112
# Epoch 61/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9790 - accuracy: 0.5215 - val_loss: 0.9817 - val_accuracy: 0.5112
# Epoch 62/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9787 - accuracy: 0.5215 - val_loss: 0.9813 - val_accuracy: 0.5112
# Epoch 63/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9784 - accuracy: 0.5215 - val_loss: 0.9810 - val_accuracy: 0.5112
# Epoch 64/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9780 - accuracy: 0.5215 - val_loss: 0.9807 - val_accuracy: 0.5112
# Epoch 65/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9777 - accuracy: 0.5215 - val_loss: 0.9805 - val_accuracy: 0.5112
# Epoch 66/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9775 - accuracy: 0.5215 - val_loss: 0.9802 - val_accuracy: 0.5112
# Epoch 67/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9772 - accuracy: 0.5215 - val_loss: 0.9800 - val_accuracy: 0.5112
# Epoch 68/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9770 - accuracy: 0.5215 - val_loss: 0.9797 - val_accuracy: 0.5112
# Epoch 69/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9767 - accuracy: 0.5215 - val_loss: 0.9794 - val_accuracy: 0.5112
# Epoch 70/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9765 - accuracy: 0.5215 - val_loss: 0.9792 - val_accuracy: 0.5112
# Epoch 71/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9763 - accuracy: 0.5215 - val_loss: 0.9790 - val_accuracy: 0.5112
# Epoch 72/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9761 - accuracy: 0.5215 - val_loss: 0.9788 - val_accuracy: 0.5112
# Epoch 73/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9759 - accuracy: 0.5215 - val_loss: 0.9786 - val_accuracy: 0.5112
# Epoch 74/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9757 - accuracy: 0.5215 - val_loss: 0.9785 - val_accuracy: 0.5112
# Epoch 75/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9756 - accuracy: 0.5215 - val_loss: 0.9782 - val_accuracy: 0.5112
# Epoch 76/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9754 - accuracy: 0.5215 - val_loss: 0.9780 - val_accuracy: 0.5112
# Epoch 77/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9752 - accuracy: 0.5215 - val_loss: 0.9779 - val_accuracy: 0.5112
# Epoch 78/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9752 - accuracy: 0.5215 - val_loss: 0.9778 - val_accuracy: 0.5112
# Epoch 79/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9751 - accuracy: 0.5215 - val_loss: 0.9777 - val_accuracy: 0.5112
# Epoch 80/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9750 - accuracy: 0.5215 - val_loss: 0.9776 - val_accuracy: 0.5112
# Epoch 81/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9749 - accuracy: 0.5215 - val_loss: 0.9774 - val_accuracy: 0.5112
# Epoch 82/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9747 - accuracy: 0.5215 - val_loss: 0.9774 - val_accuracy: 0.5112
# Epoch 83/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9747 - accuracy: 0.5215 - val_loss: 0.9771 - val_accuracy: 0.5112
# Epoch 84/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9745 - accuracy: 0.5215 - val_loss: 0.9769 - val_accuracy: 0.5112
# Epoch 85/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9743 - accuracy: 0.5215 - val_loss: 0.9767 - val_accuracy: 0.5112
# Epoch 86/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9742 - accuracy: 0.5215 - val_loss: 0.9766 - val_accuracy: 0.5112
# Epoch 87/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9741 - accuracy: 0.5215 - val_loss: 0.9765 - val_accuracy: 0.5112
# Epoch 88/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9740 - accuracy: 0.5215 - val_loss: 0.9765 - val_accuracy: 0.5112
# Epoch 89/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9740 - accuracy: 0.5215 - val_loss: 0.9764 - val_accuracy: 0.5112
# Epoch 90/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9738 - accuracy: 0.5215 - val_loss: 0.9763 - val_accuracy: 0.5112
# Epoch 91/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9738 - accuracy: 0.5215 - val_loss: 0.9762 - val_accuracy: 0.5112
# Epoch 92/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9736 - accuracy: 0.5215 - val_loss: 0.9760 - val_accuracy: 0.5112
# Epoch 93/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9735 - accuracy: 0.5215 - val_loss: 0.9760 - val_accuracy: 0.5112
# Epoch 94/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9735 - accuracy: 0.5215 - val_loss: 0.9760 - val_accuracy: 0.5112
# Epoch 95/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9734 - accuracy: 0.5215 - val_loss: 0.9759 - val_accuracy: 0.5112
# Epoch 96/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9733 - accuracy: 0.5215 - val_loss: 0.9760 - val_accuracy: 0.5112
# Epoch 97/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9734 - accuracy: 0.5215 - val_loss: 0.9759 - val_accuracy: 0.5112
# Epoch 98/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9734 - accuracy: 0.5215 - val_loss: 0.9758 - val_accuracy: 0.5112
# Epoch 99/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.9732 - accuracy: 0.5215 - val_loss: 0.9758 - val_accuracy: 0.5112
# Epoch 100/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9731 - accuracy: 0.5215 - val_loss: 0.9757 - val_accuracy: 0.5112
# Epoch 101/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9731 - accuracy: 0.5215 - val_loss: 0.9756 - val_accuracy: 0.5112
# Epoch 102/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9730 - accuracy: 0.5215 - val_loss: 0.9756 - val_accuracy: 0.5112
# Epoch 103/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9731 - accuracy: 0.5215 - val_loss: 0.9754 - val_accuracy: 0.5112
# Epoch 104/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9730 - accuracy: 0.5215 - val_loss: 0.9754 - val_accuracy: 0.5112
# Epoch 105/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9729 - accuracy: 0.5215 - val_loss: 0.9753 - val_accuracy: 0.5112
# Epoch 106/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9729 - accuracy: 0.5215 - val_loss: 0.9753 - val_accuracy: 0.5112
# Epoch 107/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9729 - accuracy: 0.5215 - val_loss: 0.9752 - val_accuracy: 0.5112
# Epoch 108/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9728 - accuracy: 0.5215 - val_loss: 0.9752 - val_accuracy: 0.5112
# Epoch 109/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9727 - accuracy: 0.5215 - val_loss: 0.9751 - val_accuracy: 0.5112
# Epoch 110/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9726 - accuracy: 0.5215 - val_loss: 0.9751 - val_accuracy: 0.5112
# Epoch 111/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9728 - accuracy: 0.5215 - val_loss: 0.9751 - val_accuracy: 0.5112
# Epoch 112/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.9727 - accuracy: 0.5215 - val_loss: 0.9750 - val_accuracy: 0.5112
# Epoch 113/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9726 - accuracy: 0.5215 - val_loss: 0.9750 - val_accuracy: 0.5112
# Epoch 114/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9726 - accuracy: 0.5215 - val_loss: 0.9749 - val_accuracy: 0.5112
# Epoch 115/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9726 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 116/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9725 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 117/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9725 - accuracy: 0.5215 - val_loss: 0.9749 - val_accuracy: 0.5112
# Epoch 118/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9725 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 119/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9724 - accuracy: 0.5215 - val_loss: 0.9747 - val_accuracy: 0.5112
# Epoch 120/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9723 - accuracy: 0.5215 - val_loss: 0.9748 - val_accuracy: 0.5112
# Epoch 121/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9723 - accuracy: 0.5215 - val_loss: 0.9747 - val_accuracy: 0.5112
# Epoch 122/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9722 - accuracy: 0.5215 - val_loss: 0.9746 - val_accuracy: 0.5112
# Epoch 123/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9722 - accuracy: 0.5215 - val_loss: 0.9747 - val_accuracy: 0.5112
# Epoch 124/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9722 - accuracy: 0.5215 - val_loss: 0.9746 - val_accuracy: 0.5112
# Epoch 125/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9721 - accuracy: 0.5215 - val_loss: 0.9746 - val_accuracy: 0.5112
# Epoch 126/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9721 - accuracy: 0.5215 - val_loss: 0.9746 - val_accuracy: 0.5112
# Epoch 127/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9721 - accuracy: 0.5215 - val_loss: 0.9745 - val_accuracy: 0.5112
# Epoch 128/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9720 - accuracy: 0.5215 - val_loss: 0.9745 - val_accuracy: 0.5112
# Epoch 129/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9720 - accuracy: 0.5215 - val_loss: 0.9745 - val_accuracy: 0.5112
# Epoch 130/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9720 - accuracy: 0.5215 - val_loss: 0.9744 - val_accuracy: 0.5112
# Epoch 131/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9744 - val_accuracy: 0.5112
# Epoch 132/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9744 - val_accuracy: 0.5112
# Epoch 133/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9719 - accuracy: 0.5215 - val_loss: 0.9743 - val_accuracy: 0.5112
# Epoch 134/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9743 - val_accuracy: 0.5112
# Epoch 135/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 136/200
# 9/9 [==============================] - 0s 14ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 137/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9742 - val_accuracy: 0.5112
# Epoch 138/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9718 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 139/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 140/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 141/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 142/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 143/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 144/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 145/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9717 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 146/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 147/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 148/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 149/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 150/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 151/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 152/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 153/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9716 - accuracy: 0.5215 - val_loss: 0.9741 - val_accuracy: 0.5112
# Epoch 154/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9740 - val_accuracy: 0.5112
# Epoch 155/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 156/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 157/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 158/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 159/200
# 9/9 [==============================] - 0s 14ms/step - loss: 0.9715 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 160/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 161/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 162/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 163/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 164/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9739 - val_accuracy: 0.5112
# Epoch 165/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9738 - val_accuracy: 0.5112
# Epoch 166/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 167/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9737 - val_accuracy: 0.5112
# Epoch 168/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 169/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 170/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 171/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 172/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 173/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 174/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9736 - val_accuracy: 0.5112
# Epoch 175/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 176/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 177/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 178/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 179/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 180/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 181/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 182/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 183/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9733 - val_accuracy: 0.5112
# Epoch 184/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 185/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 186/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 187/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 188/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 189/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 190/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 191/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 192/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 193/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 194/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 195/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112
# Epoch 196/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 197/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 198/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9713 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 199/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9734 - val_accuracy: 0.5112
# Epoch 200/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9712 - accuracy: 0.5215 - val_loss: 0.9735 - val_accuracy: 0.5112

# %%
plot_metric(training_history['fourth_model'])

# %%
history_plotter = tfdocs.plots.HistoryPlotter(metric = 'accuracy', smoothing_std=10)
history_plotter.plot(training_history)

# %% [markdown]
# ## Model ensembling
# You have learned that models can be ensembled. What is possible in `scikit-learn` is also possible in TensorFlow, just a little different as it is relying on its computation graph. However, any model is callable like a `layer` by invoking it on either an `Input` or on the output of another layer. Furthermore, you can also stack outputs together.
#
# To produce an ensemble you can define a couple of models, than use their predictions as inputs for another model and produce a final output (using `keras.Model(input, output)`). But you can also start simple and use the mean predictions over all models and then compute the `argmax()` to assign them to a class in classification (via using `layers.average([model1_preds,model2_preds,...])`). You will be surprised how well this works.
#
# Now implement your own ensemble to improve your work even a little more and to have something more to polish up your ML project on `GitHub` ;)

# %%
#===========#
# YOUR CODE #
#===========#
